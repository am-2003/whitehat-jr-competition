# %% [markdown]
# # Project: American Red Cross West Africa Project

# %% [markdown]
# ---

# %% [markdown]
# ### Context of Project
#
#   Covid-19 today has disrupted the working of the entire world. The last time a virus impacted the world to this magnitude was in 1918 (Spanish Flu). So, are viruses such a rare phenomenon or are they much more frequent than we think? The answer to this question is that there were five major outbreaks in the last twenty years.
#  Namely,
# SARS (2003)
# H1N1 Flu(2009)
# MERS (2012)
# Ebola (2015)
#  Zika(2015)
#
#   It should be noted that many of these viruses were much more deadly and had higher R0(average number of people one person will spread the virus) than covid. Then why was the impact of these viruses much lower as compared to Covid-19? The answer lies in the initial efforts taken by health organizations and governments. One of the classic examples of such an effort was during the Ebola outbreak of 2015. When the Ebola outbreak occurred in 2015 there were no maps or knowledge about the geography of the area. It was a mammoth task for the Red cross to get information about locations and then carry out work.  This project will surely make us appreciate the work of health agencies when dealing with such virus outbreak scenarios.
#
#   Maps have always played an important role in human history. Maps are of additional importance when we are facing a crisis. The majority of the world map is mapped very well in developed countries. This is not the case though in many underdeveloped west African countries. Millions of people live in an area not mapped properly.
#
#
#   During the Ebola crisis of 2014, this was a challenge for Red cross society to tackle this problem. Contact tracing was the most difficult task, particularly in the remote border areas which were the epicenter of the epidemic.
#
#   Through a private grant, the American Red Cross set out to expand its Missing Maps project to extensively map all areas within a 15 km distance of the shared borders between Guinea, Liberia, and Sierra Leone. The data were added into Open StreetMap, a free and editable world map commonly used by humanitarians.
#
# <img src="https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/borders-countries.png"/>
#
# The goal of this work is to create an open and comprehensive
# dataset of communities for West Africa and to ensure that
# decision-makers, humanitarian workers, and community
# stakeholders are better aware of water, sanitation, health,
# and community resources before and during the next crisis,
# potentially preventing or slowing the spread of infectious
# disease during future outbreaks.
#
#   We will analyze this centers on various parameters and try to answer the questions.

# %% [markdown]
# ---

# %% [markdown]
# ### Problem Statement:
#
#
# In this project, you will analyze three datasets.
#
# 1. Red cross health facility centers, given in file `redcross_westafrica_health_facilities_9.csv`. These are facilities open up by the Red cross.
#
# 2. Red cross points of interest, given in the file `redcross_westafrica_pois_10.csv`. These are additional centers that can help in the required task.
#
# 3. Red cross rapid assessment centers, given in the file `redcross_westafrica_rapidassessment_survey_csv_13.csv`. These points are where surveys are taking place in the local area.
#
# You need to answer the following questions based on this dataset.
#
# 1. Average number of beds available in health facilities and points of interest datasets. (Do not count the center if the information is not available.)
#
# 2. Average number of medical staff(doctors and nurses individually) available in these areas for both health facilities and points of interest. (Do not count the center of information is not available.)
#
# 3. Plot the graph of electricity, operator, and water source for health facilities and points of interest datasets.
#
# 4. Find a number of health facilities and points of interest open 24/7?
#
# 5. What is the average score given to drinking water, water timing, and toilet in centers where the survey is done?
#
# Following attributes are to be used in this project:
#
# For `redcross_westafrica_health_facilities_9.csv` dataset:
#
# 1. `tags_bed_count`: Number of beds in the facility.
#
# 2. `tags_doctors_num` : Number of doctors in the facility.
#
# 3. `tags_nurses_num` : Number of nurses in the facility.
#
# 4. `tags_electricity`: Type of electricity source.
#
# 5. `tags_operator`: Type of Operator of the facility.
#
# 6. `tags_water_source`: Major source of water.
#
# 7. `tags_opening_hours` : Type of opening hours.
#
# For `redcross_westafrica_pois_10.csv` dataset:
#
# 1. `tags_bed_count`: Number of beds in the facility.
#
# 2. `tags_doctors_num` : Number of doctors in the facility.
#
# 3. `tags_nurses_num` : Number of nurses in the facility.
#
# 4. `tags_electricity`: Type of electricity source.
#
# 5. `tags_operator`: Type of Operator of the facility.
#
# 6. `tags_water_source`: Major source of water.
#
# 7. `tags_opening_hours` : Type of opening hours.
#
# For `redcross_westafrica_rapidassessment_survey_csv_13.csv` dataset:
#
# 1. `drink_wat` : Score out of 100 for drinking water facility at survey center.
#
# 2. `water_time`: Score out of 100 for water timing facility at survey center.
#
# 3. `toilet` : Score out of 100 for toilet facility at survey center.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 1: Dataset.
#
# Download the data from the link provided in coding block.
#
# - Health facility center.
#
# - Points of interest.
#
# - Rapid assesment centers.

# %% [markdown]
# Read the dataset  `redcross_westafrica_health_facilities_9.csv` and store it in a dataframe `health_facilities`.
#
# Print number of rows and columns.
#
# Print first 5 entries in the dataframe.

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Read the dataset redcross_westafrica_health_facilities_9.csv and store it in a dataframe health_facilities
health_facilities = pd.read_csv("https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/redcross_westafrica_health_facilities_9.csv")

# Return the number of rows and columns
print(f"Number of rows in 'health facilities' dataset: {health_facilities.shape[0]}")
print(f"Number of columns in 'health facilities' dataset: {health_facilities.shape[1]}\n")

# Print first five rows using head() function
message1 = "Health facilities dataset: first 5 rows".upper()
print(message1)
print('-'*len(message1))
health_facilities.head()
# Out:
# Number of rows in 'health facilities' dataset: 577
# Number of columns in 'health facilities' dataset: 41
#
# HEALTH FACILITIES DATASET: FIRST 5 ROWS
# ---------------------------------------
#    type          id       lat        lon tags_addr_city tags_amenity  \
# 0  node  4131212879  7.575563  -8.539124         Yekepa     hospital
# 1  node  4131212880  8.331762 -10.066910        Balahun       clinic
# 2  node  4131212881  7.221481 -11.172409       Bamballa       clinic
# 3  node  4131212882  7.082069 -11.212406       Bangorma       clinic
# 4  node  4131212883  8.155049  -9.649732       Barzawon       clinic
#
#   tags_bed_count tags_dispensing tags_doctors_num tags_electricity  ...  \
# 0             60             yes                2        generator  ...
# 1            NaN             NaN                0              NaN  ...
# 2              4             yes                0            solar  ...
# 3              7             yes                0        generator  ...
# ...

# %% [markdown]
# Read the dataset  `redcross_westafrica_pois_10.csv` and store it in a dataframe `point_of_interest`.
#
# Print number of rows and columns.
#
# Print first 5 entries in the dataframe.

# %%
# Read the dataset  redcross_westafrica_pois_10.csv and store it in a dataframe point_of_interest
point_of_interest = pd.read_csv("https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/redcross_westafrica_pois_10.csv")

# Return the number of rows and columns
print(f"Number of rows in 'point of interest' dataset: {point_of_interest.shape[0]}")
print(f"Number of columns in 'point of interest' dataset: {point_of_interest.shape[1]}\n")

# Print first five rows using head() function
message2 = "Point of interest: first 5 rows".upper()
print(message2)
print('-'*len(message2))
point_of_interest.head()
# Out:
# Number of rows in 'point of interest' dataset: 11606
# Number of columns in 'point of interest' dataset: 44
#
# POINT OF INTEREST: FIRST 5 ROWS
# -------------------------------
#    type          id       lat        lon tags_addr_city tags_amenity  \
# 0  node   988037702  8.485455 -13.236955       Freetown   restaurant
# 1  node  4100642480  7.364712  -8.706826   Sanniquellie       school
# 2  node  4131212879  7.575563  -8.539124         Yekepa     hospital
# 3  node  4131212880  8.331762 -10.066910        Balahun       clinic
# 4  node  4131212881  7.221481 -11.172409       Bamballa       clinic
#
#                    tags_name             tags_source  \
# 0              Siakastevensr  Red Cross Field Survey
# 1        St.Mary High School  Red Cross Field Survey
# 2     Arcelormittal Hospital  Red Cross Field Survey
# 3       Balahun Faith Clinic  Red Cross Field Survey
# 4  Bamballa Community Clinic  Red Cross Field Survey
#
# ...

# %% [markdown]
# Read the dataset  `redcross_westafrica_rapidassessment_survey_csv_13.csv` and store it in a dataframe `rapidassessment`.
#
# Print number of rows and columns.
#
# Print first 5 entries in the dataframe.

# %%
# Read the dataset  redcross_westafrica_pois_10.csv and store it in a dataframe rapidassessment
rapidassessment = pd.read_csv("https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/redcross_westafrica_rapidassessment_survey_csv_13.csv")

# Return the number of rows and columns
print(f"Number of rows in 'rapidassessment' dataset: {rapidassessment.shape[0]}")
print(f"Number of columns in 'rapidassessment' dataset: {rapidassessment.shape[1]}\n")

# Print first five rows using head() function
message3 = "rapidassessment: first 5 rows".upper()
print(message3)
print('-'*len(message3))
rapidassessment.head()
# Out:
# Number of rows in 'rapidassessment' dataset: 7200
# Number of columns in 'rapidassessment' dataset: 208
#
# RAPIDASSESSMENT: FIRST 5 ROWS
# -----------------------------
#    column_a  x  hh_gps_latitude  hh_gps_longitude      namevill  \
# 0         1  1         7.212947         -9.097043        KOhoui
# 1         2  2         7.225922         -9.049043         Nimpa
# 2         3  3         7.234220         -9.087435         Gonon
# 3         4  4         7.256432         -9.057573  Soopa centre
# 4         5  5         7.261577         -9.112533       Yassata
#
#                market marketclean  marketcomsum  \
# 0      Marché de Sopa       Soopa             0
# 1     Marché de Soopa       Soopa             0
# 2      Marché de sopa       Soopa             0
# 3     Marché de soopa       Soopa             6
# 4  Marché de Bignamou    Bignamou             0
#
#                                  marketmatch  \
# 0  uuid:9490fa12-2313-44cd-8aaa-007d845c1062
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 2: Availability of beds.
#
# Find an average number of beds available in health facilities and points of interest datasets. (Do not count the center of information is not available.)
#
# **Note:** One of the entries has entry `two` instead of $2$. This may cause problems while computation. We have provided you code to do the same. It is optional to use it. Please clean the data.

# %%
# Chosen attributes for datasets
req_col_hf_poi = ['tags_bed_count',
                  'tags_doctors_num',
                  'tags_nurses_num',
                  'tags_electricity',
                  'tags_operator',
                  'tags_water_source',
                  'tags_opening_hours']

req_col_ra = ['drink_wat',
              'water_time',
              'toilet']

# %%
# Perform data cleaning
def output_data_cleaned(df):
  filter_message = f"NUMBER OF ROWS WITH FILTERED DATA: {df.shape[0]}"
  print(filter_message+'\n'+'-'*len(filter_message)+'\n')
  return df.head(10)

# %%
# Replacing two with 2
for i in range(len(health_facilities['tags_bed_count'])):
  if health_facilities['tags_bed_count'][i] == 'two':
    health_facilities['tags_bed_count'][i] = 2

# Reducing the dataset to core components defined in the problem statement
health_facilities = health_facilities[req_col_hf_poi]
health_facilities = health_facilities.dropna(axis = 0, how = 'all').reset_index(drop = True)
output_data_cleaned(health_facilities)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 354
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1            NaN                0             NaN              NaN
# 2              4                0               1            solar
# 3              7                0               2        generator
# 4              1              NaN               3            solar
# 5              9              NaN               6        generator
# 6              3              NaN               2            solar
# 7              6                0               2            solar
# 8              4                0               2        generator
# 9              2              NaN               1             none
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# I have included facilities where the number of beds was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
health_facilities_beds = health_facilities.dropna(axis = 0,subset=['tags_bed_count']).reset_index(drop = True)
output_data_cleaned(health_facilities_beds)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 335
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1              4                0               1            solar
# 2              7                0               2        generator
# 3              1              NaN               3            solar
# 4              9              NaN               6        generator
# 5              3              NaN               2            solar
# 6              6                0               2            solar
# 7              4                0               2        generator
# 8              2              NaN               1             none
# 9              4                1               6              NaN
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Replacing strings with integers, changing the data type of the beds column to integer.
values_to_replace_beds = {'00':0,'01':1,'02':2,'03':3,'04':4,'05':5,'06':6,'07':7,'08':8}
health_facilities_beds.replace(to_replace = values_to_replace_beds,inplace = True)
health_facilities_beds['tags_bed_count'] = health_facilities_beds['tags_bed_count'].astype(int)

# %%
# Find average number of beds in redcross health facilities
average_no_beds = health_facilities_beds['tags_bed_count'].mean()
sum_of_beds = int(health_facilities_beds['tags_bed_count'].sum())

# print the result
message = f"AVERAGE NUMBER OF BEDS IN REDCROSS HEALTH FACILITIES: {average_no_beds:.2f}"
print(message + '\n' + '-' * len(message))
message = f"TOTAL NUMBER OF BEDS IN REDCROSS HEALTH FACILITIES: {sum_of_beds}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF BEDS IN REDCROSS HEALTH FACILITIES: 6.64
# ----------------------------------------------------------
# TOTAL NUMBER OF BEDS IN REDCROSS HEALTH FACILITIES: 2223
# --------------------------------------------------------

# %% [markdown]
# **Q:** What is the average number of beds in the Red cross health facility?
#
# **A:** 6.64 beds (rounded up to 7 beds).

# %% [markdown]
# Now, calculate the same for points of interest for the Red cross.
#
# **Note:** One of the entries has entry `two` instead of $2$. This may cause problems while computation. We have provided you code to do the same. It is optional to use it. Please clean the data.

# %%
# Perform data cleaning

# Replacing two with 2
for i in range(len(point_of_interest['tags_bed_count'])):
  if point_of_interest['tags_bed_count'][i]=='two':
    point_of_interest['tags_bed_count'][i]=2

# Reducing dataset to chosen attributes, and getting rid of rows which have null values for all of the columns:
point_of_interest = point_of_interest[req_col_hf_poi]
point_of_interest = point_of_interest.dropna(axis = 0, how = 'all').reset_index(drop = True)
output_data_cleaned(point_of_interest)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 966
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0            NaN              NaN             NaN              NaN
# 1             60                2               6        generator
# 2            NaN                0             NaN              NaN
# 3              4                0               1            solar
# 4              7                0               2        generator
# 5              1              NaN               3            solar
# 6              9              NaN               6        generator
# 7              3              NaN               2            solar
# 8              6                0               2            solar
# 9              4                0               2        generator
#
#     tags_operator tags_water_source tags_opening_hours
# 0  pactric k.Dolo               NaN                NaN
# ...

# %%
# I have included facilities where the number of beds was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
point_of_interest_beds = point_of_interest.dropna(axis = 0,subset=['tags_bed_count']).reset_index(drop = True)
output_data_cleaned(point_of_interest_beds)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 330
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1              4                0               1            solar
# 2              7                0               2        generator
# 3              1              NaN               3            solar
# 4              9              NaN               6        generator
# 5              3              NaN               2            solar
# 6              6                0               2            solar
# 7              4                0               2        generator
# 8              2              NaN               1             none
# 9              4                1               6              NaN
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Replacing strings with integers, changing the data type of the beds column to integer.
point_of_interest_beds.replace(to_replace = values_to_replace_beds,inplace = True)
point_of_interest_beds['tags_bed_count'] = point_of_interest_beds['tags_bed_count'].astype(int)

# %%
# Calculate average
average_no_beds = point_of_interest_beds['tags_bed_count'].mean()
sum_of_beds = int(point_of_interest_beds['tags_bed_count'].sum())

# print the result
message = f"AVERAGE NUMBER OF BEDS IN REDCROSS POINTS OF INTEREST: {average_no_beds:.2f}"
print(message + '\n' + '-' * len(message))
message = f"TOTAL NUMBER OF BEDS IN REDCROSS POINTS OF INTEREST: {sum_of_beds}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF BEDS IN REDCROSS POINTS OF INTEREST: 6.72
# -----------------------------------------------------------
# TOTAL NUMBER OF BEDS IN REDCROSS POINTS OF INTEREST: 2216
# ---------------------------------------------------------

# %% [markdown]
# **Q: ** What is the average number of beds in Red cross Point of interest?
#
# **A:** 6.72 (rounded up to 7 beds to the nearest whole number)
#
#
# **Q:** Is there any significant difference in the number of beds in Red cross health centers and Red cross points of interest?
#
# **A:** No - there is a 7 bed difference between the two datasets, once cleaned.

# %%
# Boxplot for POI
median = point_of_interest_beds['tags_bed_count'].median()
quartile_one = point_of_interest_beds['tags_bed_count'].quantile(0.25)
quartile_three = point_of_interest_beds['tags_bed_count'].quantile(0.75)

plt.style.use('classic')
plt.figure(figsize = (18,6))
sns.boxplot(point_of_interest_beds['tags_bed_count'],orient = 'h')
plt.axvline(x = median, label = f'Median number of beds at points of interest: {median:.2f}', color = "red")
plt.axvline(x = quartile_one, label = f'1st Quartile of beds at points of interest: {quartile_one:.2f}', color = "blue")
plt.axvline(x = quartile_three, label = f'3rd Quartile of beds at points of interest: {quartile_three:.2f}', color = "green")
plt.legend()
plt.show()

# %% [markdown]
# From the boxplot for the point of interest beds, the median is 4 beds, which

# %%
# Boxplot for health facilities
median = health_facilities_beds['tags_bed_count'].median()
quartile_one = health_facilities_beds['tags_bed_count'].quantile(0.25)
quartile_three = health_facilities_beds['tags_bed_count'].quantile(0.75)

plt.figure(figsize = (18,6))
sns.boxplot(health_facilities_beds['tags_bed_count'],orient = 'h')
plt.axvline(x = median, label = f'Median number of beds at health facilities: {median:.2f}', color = "red")
plt.axvline(x = quartile_one, label = f'1st Quartile of beds at health facilities: {quartile_one:.2f}', color = "blue")
plt.axvline(x = quartile_three, label = f'3rd Quartile of beds at health facilities: {quartile_three:.2f}', color = "green")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 3: Medical Staff
#
# Find an average number of medical staff(doctors and nurses individually) available in these areas for both health facilities and points of interest. (Do not count the center if the information is not available.)

# %% [markdown]
# **Note:** Few of the entries are wrong. This may cause problems while computation. We have provided you code to do save your time for data cleaning. It is optional to use it. Please clean the data.
#
# There are some garbage values in the data. We will take a threshold of $100$ as the maximum number of doctors in the facility.

# %%
# Perform data cleaning
for i in range(len(health_facilities['tags_doctors_num'])):
  if health_facilities['tags_doctors_num'][i]=='Not Available' or health_facilities['tags_doctors_num'][i]=='Mamadou Bary'or health_facilities['tags_doctors_num'][i]=='guilavogui akoï' or health_facilities['tags_doctors_num'][i]=='Dr Yansane'or health_facilities['tags_doctors_num'][i]=='o' or health_facilities['tags_doctors_num'][i]=='num' or health_facilities['tags_doctors_num'][i]=='nil' or health_facilities['tags_doctors_num'][i]=='no' or health_facilities['tags_doctors_num'][i]=='none' or health_facilities['tags_doctors_num'][i]=='None'or health_facilities['tags_doctors_num'][i]=='Non' or health_facilities['tags_doctors_num'][i]=='non' or health_facilities['tags_doctors_num'][i]=='In charge':
    health_facilities['tags_doctors_num'][i]=0

# %%
# I have included facilities where the number of doctors was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
health_facilities_doctors = health_facilities.dropna(axis = 0,subset=['tags_doctors_num']).reset_index(drop = True)
output_data_cleaned(health_facilities_doctors)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 223
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1            NaN                0             NaN              NaN
# 2              4                0               1            solar
# 3              7                0               2        generator
# 4              6                0               2            solar
# 5              4                0               2        generator
# 6              4                1               6              NaN
# 7             14                0              11            solar
# 8              5                0               9            solar
# 9              6                0               2            solar
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Converting column type to integer, removing garbage values
health_facilities_doctors['tags_doctors_num'] = health_facilities_doctors['tags_doctors_num'].astype(int)
health_facilities_doctors = health_facilities_doctors[(health_facilities_doctors['tags_doctors_num'] >= 0)&(health_facilities_doctors['tags_doctors_num'] <= 100)]

# %%
# Find average number of doctors in redcross health facilities
average_no_doctors = health_facilities_doctors['tags_doctors_num'].mean()
median_no_doctors = health_facilities_doctors['tags_doctors_num'].median()

# Print the result.
message = f"AVERAGE NUMBER OF DOCTORS IN REDCROSS HEALTH FACILITIES: {average_no_doctors:.1f}"
print(message + '\n' + '-' * len(message))
message = f"MEDIAN NUMBER OF DOCTORS IN REDCROSS HEALTH FACILITIES: {median_no_doctors:.1f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF DOCTORS IN REDCROSS HEALTH FACILITIES: 0.8
# ------------------------------------------------------------
# MEDIAN NUMBER OF DOCTORS IN REDCROSS HEALTH FACILITIES: 0.0
# -----------------------------------------------------------

# %%
plt.figure(figsize = (18,6))
plt.title('HISTOGRAM FOR THE NUMBER OF DOCTORS IN REDCROSS HEALTH FACILITIES')
sns.distplot(x = health_facilities_doctors['tags_doctors_num'], bins = 'sturges', kde = False, hist = True, color = 'teal')
plt.xlabel('Number of Doctors')
plt.axvline(x = median_no_doctors, label = f'MEDIAN NO. DOCTORS: {median_no_doctors:.0f}', color = 'red',linewidth = 4)
plt.legend()
plt.show()

# %% [markdown]
# Calculate the number of nurses in the Red Cross health facility.
#
# **Note:** Few of the entries are wrong. This may cause problems while computation. We have provided you code to save your time for data cleaning. It is optional to use it. Please clean the data.
#
# There are some garbage values in the data. We will take a threshold of $100$ as the maximum number of nurses in the facility.

# %%
# Perform data cleaning
for i in range(len(health_facilities['tags_nurses_num'])):
  if health_facilities['tags_nurses_num'][i]=='Not Available' or health_facilities['tags_nurses_num'][i]== 'Mamadama CAMARA, Fatoumata CAMARA' or health_facilities['tags_nurses_num'][i]=='genaibou Bary' or health_facilities['tags_nurses_num'][i]=='zaki haba' or health_facilities['tags_nurses_num'][i]=='Dr Yansane'or health_facilities['tags_nurses_num'][i]=='o' or health_facilities['tags_nurses_num'][i]=='num' or health_facilities['tags_nurses_num'][i]=='nil' or health_facilities['tags_nurses_num'][i]=='no' or health_facilities['tags_nurses_num'][i]=='none' or health_facilities['tags_nurses_num'][i]=='None'or health_facilities['tags_nurses_num'][i]=='Non' or health_facilities['tags_nurses_num'][i]=='non' or health_facilities['tags_nurses_num'][i]=='In charge':
    health_facilities['tags_nurses_num'][i]=0

# %%
# I have included facilities where the number of nurses was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
health_facilities_nurses = health_facilities.dropna(axis = 0,subset=['tags_nurses_num']).reset_index(drop = True)
output_data_cleaned(health_facilities_nurses)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 320
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1              4                0               1            solar
# 2              7                0               2        generator
# 3              1              NaN               3            solar
# 4              9              NaN               6        generator
# 5              3              NaN               2            solar
# 6              6                0               2            solar
# 7              4                0               2        generator
# 8              2              NaN               1             none
# 9              4                1               6              NaN
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Converting column type to integer, removing garbage values
health_facilities_nurses['tags_nurses_num'] = health_facilities_nurses['tags_nurses_num'].astype(int)
health_facilities_nurses = health_facilities_nurses[health_facilities_nurses['tags_nurses_num'] <= 100]

# %%
# Find average number of nurses in redcross health facilities
average_no_nurses = health_facilities_nurses['tags_nurses_num'].mean()
median_no_nurses = health_facilities_nurses['tags_nurses_num'].median()

# Print the result.
message = f"AVERAGE NUMBER OF NURSES IN REDCROSS HEALTH FACILITIES: {average_no_nurses:.1f}"
print(message + '\n' + '-' * len(message))
message = f"MEDIAN NUMBER OF NURSES IN REDCROSS HEALTH FACILITIES: {median_no_nurses:.1f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF NURSES IN REDCROSS HEALTH FACILITIES: 2.9
# -----------------------------------------------------------
# MEDIAN NUMBER OF NURSES IN REDCROSS HEALTH FACILITIES: 2.0
# ----------------------------------------------------------

# %%
plt.figure(figsize = (18,6))
plt.title('HISTOGRAM FOR THE NUMBER OF NURSES IN REDCROSS HEALTH FACILITIES')
sns.distplot(x = health_facilities_nurses['tags_nurses_num'], bins = 'sturges', kde = False, hist = True, color = 'teal')
plt.xlabel('Number of Nurses')
plt.axvline(x = median_no_nurses, label = f'MEDIAN NO. NURSES: {median_no_nurses:.0f}', color = 'red')
plt.legend()
plt.show()

# %% [markdown]
# Calculate the average number of doctors at points of interest.
#
# **Note:** Few of the entries are wrong. This may cause problems while computation. We have provided you code to do save your time for data cleaning. It is optional to use it. Please clean the data.
#
# There are some garbage values in the data. We will take a threshold of $100$ as the maximum number of doctors in the facility.

# %%
# Perform data cleaning
for i in range(len(point_of_interest['tags_doctors_num'])):
  if point_of_interest['tags_doctors_num'][i]=='Not Available' or point_of_interest['tags_doctors_num'][i]=='Mamadou Bary'or point_of_interest['tags_doctors_num'][i]=='guilavogui akoï' or point_of_interest['tags_doctors_num'][i]=='Dr Yansane'or point_of_interest['tags_doctors_num'][i]=='o' or point_of_interest['tags_doctors_num'][i]=='num' or point_of_interest['tags_doctors_num'][i]=='nil' or point_of_interest['tags_doctors_num'][i]=='no' or point_of_interest['tags_doctors_num'][i]=='none' or point_of_interest['tags_doctors_num'][i]=='None'or point_of_interest['tags_doctors_num'][i]=='Non' or point_of_interest['tags_doctors_num'][i]=='non' or point_of_interest['tags_doctors_num'][i]=='In charge':
    point_of_interest['tags_doctors_num'][i]=0

# %%
# I have included facilities where the number of doctors was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
point_of_interest_doctors = point_of_interest.dropna(axis = 0,subset=['tags_doctors_num']).reset_index(drop = True)
output_data_cleaned(point_of_interest_doctors)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 220
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1            NaN                0             NaN              NaN
# 2              4                0               1            solar
# 3              7                0               2        generator
# 4              6                0               2            solar
# 5              4                0               2        generator
# 6              4                1               6              NaN
# 7             14                0              11            solar
# 8              5                0               9            solar
# 9              6                0               2            solar
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Converting column type to integer, removing garbage values
point_of_interest_doctors['tags_doctors_num'] = point_of_interest_doctors['tags_doctors_num'].astype(int)
point_of_interest_doctors = point_of_interest_doctors[point_of_interest_doctors['tags_doctors_num'] <= 100]

# %%
# Find average number of doctors in redcross point of interest
average_no_doctors = point_of_interest_doctors['tags_doctors_num'].mean()

# Print the result.
message = f"AVERAGE NUMBER OF DOCTORS IN REDCROSS POINTS OF INTEREST: {average_no_doctors:.1f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF DOCTORS IN REDCROSS POINTS OF INTEREST: 0.8
# -------------------------------------------------------------

# %% [markdown]
# Calculate the average number of nurses for the point of interest facility of Red cross.
#
# **Note:** Few of the entries are wrong. This may cause problems while computation. We have provided you code to do save your time for data cleaning. It is optional to use it. Please clean the data.
#
# There are some garbage values in the data. We will take a threshold of $100$ as the maximum number of nurses in the facility.

# %%
# Data cleaning
for i in range(len(point_of_interest['tags_nurses_num'])):
  if point_of_interest['tags_nurses_num'][i]=='Not Available' or point_of_interest['tags_nurses_num'][i]== 'Mamadama CAMARA, Fatoumata CAMARA' or point_of_interest['tags_nurses_num'][i]=='genaibou Bary' or point_of_interest['tags_nurses_num'][i]=='zaki haba' or point_of_interest['tags_nurses_num'][i]=='Dr Yansane'or point_of_interest['tags_nurses_num'][i]=='o' or point_of_interest['tags_nurses_num'][i]=='num' or point_of_interest['tags_nurses_num'][i]=='nil' or point_of_interest['tags_nurses_num'][i]=='no' or point_of_interest['tags_nurses_num'][i]=='none' or point_of_interest['tags_nurses_num'][i]=='None'or point_of_interest['tags_nurses_num'][i]=='Non' or point_of_interest['tags_nurses_num'][i]=='non' or point_of_interest['tags_nurses_num'][i]=='In charge':
    point_of_interest['tags_nurses_num'][i]=0

# %%
# I have included facilities where the number of nurses was not NaN since the question stated that I shouldn't include the healthcare facility if the information (in this case, the number of beds) is not avaiable.
point_of_interest_nurses = point_of_interest.dropna(axis = 0,subset=['tags_nurses_num']).reset_index(drop = True)
output_data_cleaned(point_of_interest_nurses)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 316
# --------------------------------------
#   tags_bed_count tags_doctors_num tags_nurses_num tags_electricity  \
# 0             60                2               6        generator
# 1              4                0               1            solar
# 2              7                0               2        generator
# 3              1              NaN               3            solar
# 4              9              NaN               6        generator
# 5              3              NaN               2            solar
# 6              6                0               2            solar
# 7              4                0               2        generator
# 8              2              NaN               1             none
# 9              4                1               6              NaN
#
#   tags_operator tags_water_source tags_opening_hours
# 0    private_np             piped               24/7
# ...

# %%
# Converting column type to integer, removing garbage values
point_of_interest_nurses['tags_nurses_num'] = point_of_interest_nurses['tags_nurses_num'].astype(int)
point_of_interest_nurses = point_of_interest_nurses[point_of_interest_nurses['tags_nurses_num'] <= 100]

# %%
# Find average number of nurses in redcross point of interest
average_no_nurses = point_of_interest_nurses['tags_nurses_num'].mean()

# Print the result.
message = f"AVERAGE NUMBER OF NURSES IN REDCROSS POINTS OF INTEREST: {average_no_nurses:.1f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE NUMBER OF NURSES IN REDCROSS POINTS OF INTEREST: 3.0
# ------------------------------------------------------------

# %% [markdown]
# **Q:** What is the average number of doctors present in the Red cross health facility?
#
# **A:** 0.8 (1 rounded to nearest whole number)
#
# **Q:** What is the average number of nurses present in the Red cross health facility?
#
# **A:** 2.9 (3 rounded to nearest whole number)
#
# **Q:** What is the average number of doctors present in the Red Cross point of interest health facility?
#
# **A:** 0.8 (1 rounded to nearest whole number)
#
# **Q:** What is the average number of nurses present in the Red Cross point of interest facility?
#
# **A:** 3.0 (3 rounded to nearest whole number)

# %% [markdown]
# * No boxplots for point of interest as they would produce similar results

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 4: Electricity, Operator and Water source
#
# Plot the graph of electricity, operator, and water source for health facilities and points of interest datasets.

# %% [markdown]
# Graph for health facility electricity:

# %%
# Calculate number of responses with respective option
hf_electricity_options = health_facilities['tags_electricity']
hf_electricity_options.dropna(inplace = True)
print("VALUE COUNTS: \n")
print(hf_electricity_options.value_counts(),'\n')

# Plot result
x_labels = ['Generator','Solar','None','Flash Light','Chanies Light','Oil Lamp','Lamp']
plt.style.use('classic')
plt.figure(figsize = (18,6))
plt.title('ELECTRICITY OPTIONS FOR HEALTH FACILITIES: COUNTPLOT')
sns.countplot(hf_electricity_options)
plt.xticks(ticks = np.arange(7),labels = x_labels)
plt.xlabel('ELECTRICITY OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# solar            102
# none              91
# generator         36
# flash_light        6
# chanies_light      2
# lamp               2
# oil_lamp           1
# Name: tags_electricity, dtype: int64

# %%
# PIE PLOT FOR SAME DATA
a = dict(hf_electricity_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 6
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title("ELECTRICITY OPTIONS FOR HEALTH FACILITIES: PIE CHART")
plt.pie(hf_electricity_options.value_counts(),explode = np.repeat(0.1,len(labels)), autopct = '%.2f%%', labels = labels, shadow = True, )
plt.show()

# %% [markdown]
# **Q:** What is the primary source of power at health facilities by Red cross?
#
# **A:** Solar

# %% [markdown]
# Graph for operator of health facility:

# %%
# Calculate number of responses with respective option
hf_operator_options = health_facilities['tags_operator']
hf_operator_options.dropna(inplace = True)
print("VALUE COUNTS: \n")
print(hf_operator_options.value_counts(),'\n')

# Plot result
x_labels = ['Private NP',
            'Government',
            'Combination',
            'Private Profit',
            'NGO',
            'Community Facility',
            'Ministry of Health and Sanitation',
            'District Health Management Team',
            'Private',
            'Plan Guinée (Institution)',
            'Ancien École']
plt.style.use('classic')
plt.figure(figsize = (18,6))
plt.title('OPERATOR OPTIONS FOR HEALTH FACILITIES: COUNTPLOT')
sns.countplot(hf_operator_options)
plt.xticks(ticks = np.arange(len(x_labels)),labels = x_labels,rotation=90)
plt.xlabel('OPERATOR OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# government                           174
# Ministry of Health and Sanitation     62
# private_profit                        23
# ngo                                   16
# private_np                            13
# combination                           11
# District Health Management Team        3
# private                                2
# community_facility                     1
# Plan Guinée (Institution)              1
# Ancien école                           1
# Name: tags_operator, dtype: int64

# %%
# PIE PLOT FOR SAME DATA
a = dict(hf_operator_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 7
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title("OPERATOR OPTIONS FOR HEALTH FACILITIES: PIE CHART")
plt.pie(hf_operator_options.value_counts(),explode = np.repeat(0.1,len(labels)), autopct = '%.2f%%', labels = labels, shadow = True, )
plt.show()

# %% [markdown]
# **Q:** Who operated majority of health facilities?
#
# **A:** The government

# %% [markdown]
# Graph for water source at health facilities of Red cross.:

# %%
# Calculate number of responses with respective option
hf_water_source_options = health_facilities['tags_water_source']
hf_water_source_options.dropna(inplace = True)
print("VALUE COUNTS: \n")
print(hf_water_source_options.value_counts(),'\n')

# Plot result
x_labels = ['Piped',
            'Pub Tap',
            'Protected Well',
            'Hand Pump',
            'Tubewell',
            'Surface Water',
            'Pumped Water',
            'Unprotected Well',
            'Rain',
            'Unprotected Spring',
            'Protected Spring',
            'Tanker Truck',
            'Cart',
            'Hand pump in the community',
            'Public Hand pump',
            'Protected hand pump from the community']
plt.style.use('classic')
plt.figure(figsize = (18,6))
plt.title('WATER SOURCE OPTIONS FOR HEALTH FACILITIES: COUNTPLOT')
sns.countplot(hf_water_source_options)
plt.xticks(ticks = np.arange(len(x_labels)),labels = x_labels,rotation=90)
plt.xlabel('WATER SOURCE OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# pub_tap                                    64
# protected_well                             56
# piped                                      39
# tubewell                                   12
# protected_spring                           12
# unprotected_spring                         10
# pump_water                                  7
# unprotected_well                            7
# surface_water                               6
# hand_pump                                   4
# rain                                        4
# tanker_truck                                1
# cart                                        1
# Hand pump in the Community.                 1
# public hand pump                            1
# protected Hand pump from the community.     1
# Name: tags_water_source, dtype: int64

# %%
# PIE PLOT FOR SAME DATA
a = dict(hf_water_source_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 7
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title("WATER SOURCE OPTIONS FOR HEALTH FACILITIES: PIE CHART")
plt.pie(hf_water_source_options.value_counts(),explode = np.repeat(0.1,len(labels)), autopct = '%.2f%%', labels = labels, shadow = True, )
plt.show()

# %% [markdown]
# **Q:** Name $3$ major source of water at health facilities of red cross?
#
# **A:** Public Tap water, Protected Well, Piped Water

# %% [markdown]
# Graph for electricity at point of interest of red cross:

# %%
poi_electricity_options = point_of_interest['tags_electricity']
poi_electricity_options.dropna(inplace = True)
print("VALUE COUNTS:\n")
print(poi_electricity_options.value_counts(),'\n')

# Plot result
x_labels = ['Generator','Solar','None','Flash Light','Chanies Light','Oil Lamp','Lamp']
plt.style.use('classic')
plt.figure(figsize = (18,6))
plt.title('ELECTRICITY OPTIONS FOR POINT OF INTEREST: COUNTPLOT')
sns.countplot(poi_electricity_options)
plt.xticks(ticks = np.arange(7),labels = x_labels)
plt.xlabel('ELECTRICITY OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# solar            101
# none              87
# generator         37
# flash_light        5
# chanies_light      2
# oil_lamp           1
# lamp               1
# Name: tags_electricity, dtype: int64

# %%
# PIE PLOT FOR SAME DATA
a = dict(poi_electricity_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 6
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title("ELECTRICITY OPTIONS FOR POINT OF INTEREST: PIE CHART")
plt.pie(poi_electricity_options.value_counts(),explode = np.repeat(0.1,len(labels)), autopct = '%.2f%%', labels = labels, shadow = True, )
plt.show()

# %% [markdown]
# **Q:** Two major source of electricity at point of interest?
#
# **A:** Solar, Generator

# %% [markdown]
# Graph for operator at point of interest of Red cross:

# %%
# Calculate number of responses with respective option
poi_operator_options = point_of_interest['tags_operator']
poi_operator_options.dropna(inplace = True)
print("VALUE COUNTS:\n")
print(poi_operator_options.value_counts(),'\n')

# Plot result
plt.style.use('classic')
plt.figure(figsize = (25,5))
plt.title('OPERATOR OPTIONS FOR POINT OF INTEREST: COUNTPLOT')
sns.countplot(poi_operator_options)
plt.xticks(rotation = 90, fontsize = 7)
plt.xlabel('OPERATOR OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# government                           184
# Ministère de l'Éducation              78
# Ministry of Health and Sanitation     62
# Privée                                26
# private_profit                        23
#                                     ...
# Groupe Scolaire Guilavo                1
# Arkey Kpador                           1
# Plan Guinée (Institution)              1
# Ancien école                           1
# Mr Keita                               1
# Name: tags_operator, Length: 179, dtype: int64

# %%
a = dict(poi_operator_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 5
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title('OPERATOR OPTIONS FOR POINT OF INTEREST: PIE CHART')
plt.pie(poi_operator_options.value_counts(),labels = labels, autopct = '%.2f%%', shadow = True)
plt.show()

# %% [markdown]
# **Q:** Are majority of operators private ?
#
# **A:** Assuming that all of the small operators are private, the **majority** of operators for points of interest appears to be private, as the top 3 government operators account for 44.32% of the healthcare facilities, but the remaining 56.68% are assumed to be private operators.

# %% [markdown]
# Graph for water source at point of interest of Red cross.

# %%
# Calculate number of responses with respective option
poi_water_source_options = point_of_interest['tags_water_source']
poi_water_source_options.dropna(inplace = True)
print("VALUE COUNTS:\n")
print(poi_water_source_options.value_counts(),'\n')

# Plot result
x_labels = ['Piped',
            'Pub Tap',
            'Protected Well',
            'Hand Pump',
            'Tubewell',
            'Surface Water',
            'Pumped Water',
            'Unprotected Well',
            'Rain',
            'Unprotected Spring',
            'Protected Spring',
            'Tanker Truck',
            'Cart',
            'Hand pump in the community',
            'Public Hand pump',
            'Protected hand pump from the community']
plt.style.use('classic')
plt.figure(figsize = (18,6))
plt.title('WATER SOURCE OPTIONS FOR POINT OF INTEREST: COUNTPLOT')
sns.countplot(poi_water_source_options)
plt.xticks(ticks = np.arange(len(x_labels)),labels = x_labels,rotation=90)
plt.xlabel('WATER SOURCE OPTIONS')
plt.ylabel('NUMBER OF TIMES IMPLEMENTED')
plt.show()
# Out:
# VALUE COUNTS:
#
# pub_tap                                    64
# protected_well                             53
# piped                                      39
# protected_spring                           12
# tubewell                                   11
# unprotected_spring                          9
# pump_water                                  7
# unprotected_well                            7
# surface_water                               6
# rain                                        4
# hand_pump                                   3
# tanker_truck                                1
# cart                                        1
# Hand pump in the Community.                 1
# public hand pump                            1
# protected Hand pump from the community.     1
# Name: tags_water_source, dtype: int64

# %%
a = dict(poi_water_source_options.value_counts())
res = dict((v,k) for k,v in a.items())
b = 6
first_three = list(res.values())[:b]
to_be_concat = list(np.repeat('',len(a)-b))
labels = first_three + to_be_concat

plt.figure(dpi = 96)
plt.title("WATER SOURCE OPTIONS FOR POINT OF INTEREST: PIE CHART")
plt.pie(poi_water_source_options.value_counts(),explode = np.repeat(0.1,len(labels)), autopct = '%.2f%%', labels = labels, shadow = True, )
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 5: Availability
#
# Find the number of health facilities and point of interest facilities open 24/7?

# %%
# health facilities known to be open 24/7
health_facilities_all_time = health_facilities[health_facilities['tags_opening_hours'] == '24/7']
message = f"NUMBER OF HEALTH FACILITIES OPEN 24/7: {health_facilities_all_time.shape[0]}"
print(message + '\n' + '-' * len(message))
# Out:
# NUMBER OF HEALTH FACILITIES OPEN 24/7: 91
# -----------------------------------------

# %%
# point of interest centers known to be open 24/7
poi_all_time = point_of_interest[point_of_interest['tags_opening_hours'] == '24/7']
message = f"NUMBER OF POINTS OF INTEREST OPEN 24/7: {poi_all_time.shape[0]}"
print(message + '\n' + '-' * len(message))
# Out:
# NUMBER OF POINTS OF INTEREST OPEN 24/7: 134
# -------------------------------------------

# %% [markdown]
# **Q:** Which type of facility have more rate of being open 24/7 ?
#
# **A:** Point of Interest

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 6: Water and sanitation.
#
# What is the average score is given to drinking water, water timing, and toilet in centers where the survey is done.
#
# A score is given out of 100 for the same. There are some garbage values. Hence, we only need to consider entry if it has a score $0-100$.

# %%
# Reduce dataframe to selected attributes
rapidassessment = rapidassessment[req_col_ra]
output_data_cleaned(rapidassessment)
# Out:
# NUMBER OF ROWS WITH FILTERED DATA: 7200
# ---------------------------------------
#    drink_wat  water_time  toilet
# 0          3          20      10
# 1          3          90      10
# 2          3          90      10
# 3          3          60      10
# 4         11          30      10
# 5          3          20       6
# 6          3          60      10
# 7          8          60      10
# 8          3           2      10
# 9          3           3      10

# %%
# Filter garbage values
rapidassessment_dw = rapidassessment[(rapidassessment['drink_wat']>=0)&(rapidassessment['drink_wat']<=100)]

# Calculate Average
message = f"AVERAGE OF DRINKING WATER SCORES: {rapidassessment_dw['drink_wat'].mean():.2f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE OF DRINKING WATER SCORES: 9.85
# --------------------------------------

# %% [markdown]
# Calculate average facility for water timing at area of survey:

# %%
# Filter garbage values
rapidassessment_wt = rapidassessment[(rapidassessment['water_time']>=0)&(rapidassessment['water_time']<=100)]

# Calculate Average
message = f"AVERAGE OF WATER TIMING SCORES: {rapidassessment_wt['water_time'].mean():.2f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE OF WATER TIMING SCORES: 24.78
# -------------------------------------

# %% [markdown]
# Calculate the average score for toilet at area of survey.

# %%
# Filter garbage values
rapidassessment_t = rapidassessment[(rapidassessment['toilet']>=0)&(rapidassessment['toilet']<=100)]

# Calculate Average
message = f"AVERAGE OF TOILET SCORES: {rapidassessment_t['toilet'].mean():.2f}"
print(message + '\n' + '-' * len(message))
# Out:
# AVERAGE OF TOILET SCORES: 8.15
# ------------------------------

# %% [markdown]
# **Q:** On which parameter the score is maximum ?
#
# **A:** Water timing

# %% [markdown]
# ---

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# ---

# %% [markdown]
# **Please refer to the uploaded 2021-06-12_Aditya_Mahesh_SVC_Conclusions_And_Recommendations.pdf with inline images.**
#
# ## Summary
#
# The goal of this project was to analyse the open and comprehensive datasets from the Ebola epidemic, which included data pertaining to water sources, sanitation, health and community resources in Sierra Leone, Guinea and Liberia. The next objective was to present the conclusions and recommendations, based on the above analysis, to better handle future outbreaks in these countries.
#
# ## Conclusions
#
# The three datasets issued for analysis were the data for the:
# 1.	 Red Cross Health Facility Centres – facilities opened up by the Red Cross
# 2.	The Red Cross Points of Interest (i.e., additional centres that could help in the required task)
# 3.	The Red Cross rapid assessment centres – where surveys were taking place in the local area.
#
# The analysis found there were 7 beds, on average, found per health facility and point of interest. The median number of beds was 4 (for both health facilities and points of interest). This calculation ruled out centres which had null values for the number of beds. The number of healthcare facilities was 335 and the number of points of interest was 330. There were 2223 beds in the health facilities dataset and 2216 beds in the point of interest dataset. Hence the difference between the total number of beds was 7, which was insignificant.
#
#
#
# Similarly, it was found that there was, on average, 1 doctor and 3 nurses per health facility and point of interest. The median number of doctors was 0 and the median number of nurses was 2. Again, information with no data has not been included.
#
# The graphs for power source for health facilities and points of interest revealed that the major source of electrical power was solar (about 43%), followed by generator (15%). Approximately 38% of facilities had no electrical power supply.
#
#
# There was a significant difference in the operators data between the point of interest facilities and the healthcare facilities. For health facilities, a whopping 56.68% of healthcare facilities were operated by the government. The ministry of education and the ministry of health and sanitation played an important role in the operations too. On the other hand, assuming that all of the small operators were private, the majority of operators for points of interest appeared to be private, as the top 3 government operators accounted for only 44.32% of the healthcare facilities, but the remaining 55.68% were assumed to be private operators.
#
#
# The pie plots for the water source options for point of interest and health facilities presented very similar data. The three major sources of water were public tap water (29%), followed by protected well (25%) and piped water (17%).
#
#
# The analysis also found that there were 91 health facilities and 134 points of interest open 24/7. Therefore, the point of interest facilities were more likely to be open 24/7 than the healthcare facilities. In addition, the average of the drinking water scores was 9.85/100, the average of the water timing scores was 24.78/100 and the average of the toilet scores was 8.15/100, in centres where the survey was done. Hence, the water timing parameter scored the maximum.

# %% [markdown]
# ### Recommendations:

# %% [markdown]
# ---

# %% [markdown]
# Based on the conclusions deduced from the data analysis, I propose the following recommendations.
#
# 1.	The average number of beds seemed to be promising for both healthcare facilities and points of interest. For a total number of 330 point of interest facilities, and 335 healthcare facilities, there was an average of 7 beds. There were several large outliers which increased the value of the mean: when plotting the boxplot for the distribution of number of beds, the median was found to be 4. I recommend increasing the median value by increasing the number of beds by 50% of the median (n = 2).
#
# 2.	The current average number of doctors and nurses per facility seemed quite reasonable. However, the median number of doctors and nurses was less, which explained the skewed distribution of doctors and nurses across health facilities.  I recommend paying immediate attention to the areas where there are no doctors and/or nurses.
#
# 3.	It’s commendable that solar power provided energy to power about 43% of the facilities. However, 38% facilities didn’t have access to any electrical power. I recommend that more WHO funding / Government funding should be allocated to the creation of more solar farms to generate sufficient electricity to power those healthcare facilities.
#
# 4.	On the one hand, the government had been able to operate more facilities than the private organisations for the health facilities. On the other hand, there were several private operators for the points of interest that decentralised the operation modes, which was not scalable or reliable. Therefore, the government would need to take control of the operations that are in the hands of the private sector.
#
# 5.	About 70% of the facilities had access to the three main sources of potable water. However, there was still a reasonable percentage of facilities with no access to potable water. To contain future outbreaks there should be a sustainable water infrastructure in place.
#
# 6.	It is recommended that point of interest and healthcare facilities are maintained to give 24/7 access to the patients.
#
# 7.	The average of the drinking water, water timing and toilet scores in the healthcare facilities should be maintained at least at 9.85, 24.78 and 8.15/100 respectively, and further measures should be taken as recommended above to improve the values.
#
# The data analysis found a great work had been underway by Red Cross and the government to provide the necessary healthcare facilities which contained the Ebola epidemic. So, I strongly believe the above recommendations would further help the decision-makers, humanitarian workers, and community stakeholders, as well as the governments and Red Cross in containing any more deadly or contagious outbreaks.

# %% [markdown]
# **Dataset License:** [link](https://data.humdata.org/about/license)
